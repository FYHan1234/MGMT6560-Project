# %% [markdown]
# ## MGMT 6560 Project

# %% [markdown]
# ### Model 1: Simple Linear Regression Model

# %% [markdown]
# #### Part 1

# %%
#Basic Imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Load the data
train=pd.read_csv('./input/train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Load the data
test=pd.read_csv('./input/test.csv')
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# #### Part 2 Fill NaN values in the training set

# %%
#Drop the Id column and SalePrice column in the training set. 
#The Id column will not be used in the model. And SalePrice will be the y for the training.
train=train.drop(['SalePrice'],axis=1)
train=train.drop(['Id'],axis=1)
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Corner      ...                 0        0    NaN
# 4         Lvl    AllPub       FR2      ...                 0        0    NaN
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#Drop the Id column in the test set
#The Id column will not be used in the model.
test=test.drop(['Id'],axis=1)
test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RH         80.0    11622   Pave   NaN      Reg
# 1          20       RL         81.0    14267   Pave   NaN      IR1
# 2          60       RL         74.0    13830   Pave   NaN      IR1
# 3          60       RL         78.0     9978   Pave   NaN      IR1
# 4         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...               120        0    NaN
# 1         Lvl    AllPub    Corner      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Inside      ...                 0        0    NaN
# 4         HLS    AllPub    Inside      ...               144        0    NaN
#
#    Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#This code shows all numerical columns in the training set.
train._get_numeric_data().columns
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Corner      ...                 0        0    NaN
# 4         Lvl    AllPub       FR2      ...                 0        0    NaN
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#For convenience I use this code to check how many null values are in these numerical (literally) columns
train[train._get_numeric_data().columns].isnull().sum()
# Out:
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
#It seems that only two columns listed above have NaN values. 
#Fill NaN of the LotFrontage Column
train['LotFrontage']=train['LotFrontage'].fillna(train['LotFrontage'].mean())
#the 7th row in the LotFrontage column was NaN. I want to check whether it is filled
train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL    65.000000     8450   Pave   NaN      Reg
# 1             20       RL    80.000000     9600   Pave   NaN      Reg
# 2             60       RL    68.000000    11250   Pave   NaN      IR1
# 3             70       RL    60.000000     9550   Pave   NaN      IR1
# 4             60       RL    84.000000    14260   Pave   NaN      IR1
# 5             50       RL    85.000000    14115   Pave   NaN      IR1
# 6             20       RL    75.000000    10084   Pave   NaN      Reg
# 7             60       RL    70.049958    10382   Pave   NaN      IR1
# 8             50       RM    51.000000     6120   Pave   NaN      Reg
# 9            190       RL    50.000000     7420   Pave   NaN      Reg
# 10            20       RL    70.000000    11200   Pave   NaN      Reg
# 11            60       RL    85.000000    11924   Pave   NaN      IR1
# ...

# %%
#Based on previous results, GarageYrBlt column has 81 NaN. 
#This column looks like a numerical one but it is not. So fill NaN with 'None'
#NaN simply indictes: there is no garage at this property.
#Later this column will be treated using get_dummmies function as other categorical columns
train['GarageYrBlt']=train['GarageYrBlt'].fillna('None')

# %%
#Now all NaN values in columns with numbers are filled. Now deal with NaN in other columns
#In these columns, NaN means 'None', as this property does not have something
#One function will get the job done. 
train=train.fillna('None')
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  None      Reg
# 1          20       RL         80.0     9600   Pave  None      Reg
# 2          60       RL         68.0    11250   Pave  None      IR1
# 3          70       RL         60.0     9550   Pave  None      IR1
# 4          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0   None
# 1         Lvl    AllPub       FR2      ...                 0        0   None
# 2         Lvl    AllPub    Inside      ...                 0        0   None
# 3         Lvl    AllPub    Corner      ...                 0        0   None
# 4         Lvl    AllPub       FR2      ...                 0        0   None
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# #### Part 3 Fill NaN values in the test set
